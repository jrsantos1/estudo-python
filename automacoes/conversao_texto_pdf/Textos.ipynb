# %%
#Abrir o arquivo de texto
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt')
linhas = arquivo.readlines()

print(linhas)
# Out:
# ['Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas\n', 'ABC;Rosiane;782707;Aline Rosa;5;10;7;7;2\n', 'Filho;Carolina;437686;Amanda Martins;6;10;10;9;3\n', 'ABC;Rosiane;310916;Angela Maria;8;10;7;10;5\n', 'ABC;Carolina;760926;Carlos Moreira;10;4;7;6;2\n', 'Filho;Rosiane;557848;Eliane Moreira;10;6;5;4;3\n', 'ABC;Rosiane;758465;Leonardo Almeida;8;9;6;9;2\n', 'ABC;Carolina;235215;Nicolas Pereira;1;2;2;2;3\n', 'ABC;Rosiane;751595;Paulo Santos;9;7;10;9;0\n', 'ABC;Carolina;760936;Raul Silva;8;10;5;10;4\n', 'Filho;Rosiane;557858;Reinaldo Assis;8;8;8;5;5\n', 'ABC;Carolina;758475;Eduardo Pires;8;9;8;9;1\n']

# %%
#Abrir o arquivo de texto
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
    nome = separaLinhaEmColunas[2]
    
    print(nome)
# Out:
# Aluno
# Aline Rosa
# Amanda Martins
# Angela Maria
# Carlos Moreira
# Eliane Moreira
# Leonardo Almeida
# Nicolas Pereira
# Paulo Santos
# Raul Silva
# Reinaldo Assis
# Eduardo Pires

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado

arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
    nome = separaLinhaEmColunas[2]    
    
    
    #Eu verifico se é o titulo
    if separaLinhaEmColunas[3] == "Nota 1":
        
        #print(nome)
        print("------ Título ---------")
    
    #Faço os calculos e tratamento a partir da segunda linha
    else:
        
        print(nome)
        
        nota1 = int(separaLinhaEmColunas[3])
        nota2 = int(separaLinhaEmColunas[4])
        nota3 = int(separaLinhaEmColunas[5])
        nota4 = int(separaLinhaEmColunas[6])
        faltas = int(separaLinhaEmColunas[7])
        
        print("Nota 1: ", nota1)
        print("Nota 2: ", nota2)
        print("Nota 3: ", nota3)
        print("Nota 4: ", nota4)
        print("Faltas: ", faltas)
        
        media = (nota1 + nota2 + nota3 + nota4) / 4
        
        print("Média: ", media)
        
        if faltas >= 4:
            
            print("Reprovado(a) por falta")
            
        else:
            
            #if - Se / elif - Senão Se
            if media >= 6:
                
                print("Aprovado(a)")
                
            elif media >= 4:
                
                print("Recuperação")
                
            else:
                
                print("Reprovado(a) por Média")
                
        print("-----------------------")
# Out:
# ------ Título ---------
# Aline Rosa
# Nota 1:  5
# Nota 2:  10
# Nota 3:  7
# Nota 4:  7
# Faltas:  2
# Média:  7.25
# Aprovado(a)
# -----------------------
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Angela Maria
# Nota 1:  8
# Nota 2:  10
# Nota 3:  7
# Nota 4:  10
# Faltas:  5
# Média:  8.75
# Reprovado(a) por falta
# -----------------------
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Eliane Moreira
# Nota 1:  10
# Nota 2:  6
# Nota 3:  5
# Nota 4:  4
# Faltas:  3
# Média:  6.25
# Aprovado(a)
# -----------------------
# Leonardo Almeida
# Nota 1:  8
# Nota 2:  9
# Nota 3:  6
# Nota 4:  9
# Faltas:  2
# Média:  8.0
# Aprovado(a)
# -----------------------
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Paulo Santos
# Nota 1:  9
# Nota 2:  7
# Nota 3:  10
# Nota 4:  9
# Faltas:  0
# Média:  8.75
# Aprovado(a)
# -----------------------
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Reinaldo Assis
# Nota 1:  8
# Nota 2:  8
# Nota 3:  8
# Nota 4:  5
# Faltas:  5
# Média:  7.25
# Reprovado(a) por falta
# -----------------------
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado
#Verifica se a professora é Carolina e exibe somente os alunos dela

arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego a posição 0 que é o nome da professora
    professora = separaLinhaEmColunas[0]  
    
    if professora == "Carolina":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")

                elif media >= 4:

                    print("Recuperação")

                else:

                    print("Reprovado(a) por Média")

            print("-----------------------")
# Out:
# Professora:  Carolina
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Professora:  Carolina
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado
#Verifica se a professora é Carolina e exibe somente os alunos dela
#Passa os dados da professora Carolina para o arquivo arquivoProfessoraCarolina

#w - Escrever no arquivo de texto
#r - Ler os dados do arquivo de texto
arquivoProfessoraCarolina = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', 'w')
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt', 'r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego a posição 0 que é o nome da professora
    professora = separaLinhaEmColunas[0]  
    
    if professora == "Carolina":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por Média\n')


            print("-----------------------")
# Out:
# Professora:  Carolina
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Professora:  Carolina
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado
#Verifica se a professora é Carolina ou Rosiane e exibe somente os alunos delas
#Passa os dados da professora Carolina para o arquivo arquivoProfessoraCarolina
#Passa os dados da professora Rosiane para o arquivo arquivoProfessoraRosiane

#w - Escrever no arquivo de texto
#r - Ler os dados do arquivo de texto
arquivoProfessoraCarolina = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', 'w')
arquivoProfessoraRosiane = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.txt', 'w')
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt', 'r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego a posição 0 que é o nome da professora
    professora = separaLinhaEmColunas[0]  
    
    if professora == "Carolina":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por Média\n')


            print("-----------------------")
            
    elif professora == "Rosiane":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraRosiane.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(nome + ', Média: ' + str(media) + ', Faltas: ' + str(faltas) + ' - Reprovado(a) por Média\n')


            print("-----------------------")
# Out:
# Professora:  Rosiane
# Aline Rosa
# Nota 1:  5
# Nota 2:  10
# Nota 3:  7
# Nota 4:  7
# Faltas:  2
# Média:  7.25
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Angela Maria
# Nota 1:  8
# Nota 2:  10
# Nota 3:  7
# Nota 4:  10
# Faltas:  5
# Média:  8.75
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Eliane Moreira
# Nota 1:  10
# Nota 2:  6
# Nota 3:  5
# Nota 4:  4
# Faltas:  3
# Média:  6.25
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Leonardo Almeida
# Nota 1:  8
# Nota 2:  9
# Nota 3:  6
# Nota 4:  9
# Faltas:  2
# Média:  8.0
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Professora:  Rosiane
# Paulo Santos
# Nota 1:  9
# Nota 2:  7
# Nota 3:  10
# Nota 4:  9
# Faltas:  0
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Rosiane
# Reinaldo Assis
# Nota 1:  8
# Nota 2:  8
# Nota 3:  8
# Nota 4:  5
# Faltas:  5
# Média:  7.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py): started
#   Building wheel for fpdf (setup.py): finished with status 'done'
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40722 sha256=aa87f6c3cf845835a7420babd9c5d9677f6e72f1e042c5efa6f12a1f469a17c4
#   Stored in directory: c:\users\55119\appdata\local\pip\cache\wheels\b4\7f\00\f90ea7c44f8b921477205baa66a7aaf04be398f743ea946fd5
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#Converter um arquivo de texto para um arquivo pdf

from fpdf import FPDF

#Salva com o auxilio da classe FPDF
pdf = FPDF()

#Adiciono uma nova página em branco ao arquivo PDF
pdf.add_page()

#Definindo estilo e tamanho da fonte / letra / texto
pdf.set_font("Arial", size = 12)

#Abre o arquivo de texto no modo de leitura
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.txt', 'r')

#w = Largura da célula
w = 0

#h = Altura da célula
h = 0

for linha in arquivo:
    
    #txt - Texto para imprimir. Valor padrão: String
    #border - Indica se as bordas devem ser desenhadas ao redor da célula
    #0 - Não tem borda
    #1 - Frame
    
    #ln - Indica onde a posição inicial deve ir após abrir o arquivo
    #0 - Para direita
    #1 - Para o inicio da próxima
    #2 - Abaixo
    
    
    #align - Permite o alinhamento da célula
    #L - Alinhamento a esquerda
    #C - Centro
    #R - Alinhar a direita
    
    #fill - Indica se o fundo da célula deve ser pintado pintado (true) ou transparente  (false)
    pdf.cell(w, h = 10, txt = linha, border = 1, ln = 1,
            align = 'L', fill = False, link = 'https://www.google.com/')
    
pdf.output("A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.pdf")
# Out:
# ''

# %%
#Converter um arquivo de texto para um arquivo pdf

from fpdf import FPDF

#Salva com o auxilio da classe FPDF
pdf = FPDF()

#Adiciono uma nova página em branco ao arquivo PDF
pdf.add_page()

#Definindo estilo e tamanho da fonte / letra / texto
pdf.set_font("Arial", size = 15)

#Criando uma nova célula
#Criando um título
pdf.cell(200, 10, txt = "Escola ABC", ln = 1,
            align = 'C')

#Criando um subtitulo
#Criando uma nova célula / linha
pdf.cell(200, 10, txt = "Turma 5 / 2023", ln = 1,
            align = 'C')

#Criando uma nova célula / linha em branco
pdf.cell(200, 10, txt = "", ln = 1,
            align = 'C')

#Definindo estilo e tamanho da fonte / letra / texto
pdf.set_font("Arial", size = 12)

#Abre o arquivo de texto no modo de leitura
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.txt', 'r')

#w = Largura da célula
w = 0

#h = Altura da célula
h = 0

for linha in arquivo:
    
    #txt - Texto para imprimir. Valor padrão: String
    #border - Indica se as bordas devem ser desenhadas ao redor da célula
    #0 - Não tem borda
    #1 - Frame
    
    #ln - Indica onde a posição inicial deve ir após abrir o arquivo
    #0 - Para direita
    #1 - Para o inicio da próxima
    #2 - Abaixo
    
    
    #align - Permite o alinhamento da célula
    #L - Alinhamento a esquerda
    #C - Centro
    #R - Alinhar a direita
    
    #fill - Indica se o fundo da célula deve ser pintado pintado (true) ou transparente  (false)
    pdf.cell(w, h = 10, txt = linha, border = 1, ln = 1,
            align = 'L', fill = False, link = 'https://www.google.com/')

#Salva o arquivo PDF
pdf.output("A:\\Python RPA\\Arquivo Texto e PDF\\PDF Professora Rosiane.pdf")


print("PDF criado com sucesso!")
# Out:
# PDF criado com sucesso!

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\55119\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\55119\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\55119\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\55119\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\55119\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado
#Verifica se a professora é Carolina e exibe somente os alunos dela
#Passa os dados da professora Carolina para o arquivo arquivoProfessoraCarolina

import pandas as pd

#w - Escrever no arquivo de texto
#r - Ler os dados do arquivo de texto
arquivoProfessoraCarolina = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', 'w')
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt', 'r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#Titulo
arquivoProfessoraCarolina.write('ID;Aluno;Média;Faltas;Situação\n')

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego a posição 0 que é o nome da professora
    professora = separaLinhaEmColunas[0]  
    
    if professora == "Carolina":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por Média\n')


            print("-----------------------")
            

#Fecho o arquivo da professora Carolina
arquivoProfessoraCarolina.close()
            

#enconding = 'cp1252'
#enconding = 'ISO-8859-1'

#Lê o arquivo de texto e corrige os acentos com o encoding
configuracaoIdioma = 'cp1252'
arquivoDataFrame = pd.read_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', encoding=configuracaoIdioma )

#Salva o arquivo em formato de tabela no excel
arquivoDataFrame.to_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.csv', encoding='utf-8-sig')
# Out:
# Professora:  Carolina
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Professora:  Carolina
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
#Abrir o arquivo de texto
#calcula média e exibe o resultado
#Verifica se a professora é Carolina ou Rosiane e exibe somente os alunos delas
#Passa os dados da professora Carolina e Rosiane para o arquivo arquivoProfessoraCarolina e arquivoProfessoraRosiane
#Salva ambos os arquivos no Excel

import pandas as pd

#w - Escrever no arquivo de texto
#r - Ler os dados do arquivo de texto
arquivoProfessoraCarolina = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', 'w')
arquivoProfessoraRosiane = open('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.txt', 'w')
arquivo = open('A:\\Python RPA\\Arquivo Texto e PDF\\Alunos.txt', 'r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

#Titulo
arquivoProfessoraCarolina.write('ID;Aluno;Média;Faltas;Situação\n')
arquivoProfessoraRosiane.write('ID;Aluno;Média;Faltas;Situação\n')

#for - para
#para cada linha do arquivoBlocoDeNotas
for linha in arquivoBlocoDeNotas:
    
    #Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas
    #split - Quebra o texto em partes
    quebraLinha = linha.split(',')
    
    #print(quebraLinha)
    
    #Faz uma única divisão e paga os itens a partir da coluna 1
    linha = [item.split(';', 1)[1] for item in quebraLinha]
    
    #Separando a linhas em colunas através o delimitador que é o ;
    separaLinhaEmColunas = linha[0].split(';')
    
    #print(separaLinhaEmColunas)
    
    #Pego a posição 0 que é o nome da professora
    professora = separaLinhaEmColunas[0]  
    
    if professora == "Carolina":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraCarolina.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por Média\n')


            print("-----------------------")
            
    elif professora == "Rosiane":
        
        print("Professora: ", professora)
    
        #Pego o nome do aluno que está na coluna 3 por que sempre começa na coluna 0
        nome = separaLinhaEmColunas[2]    


        #Eu verifico se é o titulo
        if separaLinhaEmColunas[3] == "Nota 1":

            #print(nome)
            print("------ Título ---------")

        #Faço os calculos e tratamento a partir da segunda linha
        else:

            print(nome)

            nota1 = int(separaLinhaEmColunas[3])
            nota2 = int(separaLinhaEmColunas[4])
            nota3 = int(separaLinhaEmColunas[5])
            nota4 = int(separaLinhaEmColunas[6])
            faltas = int(separaLinhaEmColunas[7])

            print("Nota 1: ", nota1)
            print("Nota 2: ", nota2)
            print("Nota 3: ", nota3)
            print("Nota 4: ", nota4)
            print("Faltas: ", faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:

                print("Reprovado(a) por falta")
                
                #Escrevendo os itens e o resultado no arquivo de texto
                arquivoProfessoraRosiane.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por falta\n')

            else:

                #if - Se / elif - Senão Se
                if media >= 6:

                    print("Aprovado(a)")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Aprovado(a)\n')


                elif media >= 4:

                    print("Recuperação")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Recuperação\n')


                else:

                    print("Reprovado(a) por Média")
                    
                    #Escrevendo os itens e o resultado no arquivo de texto
                    arquivoProfessoraRosiane.write(';' + nome + '; Média: ' + str(media) + '; Faltas: ' + str(faltas) + '; Reprovado(a) por Média\n')


            print("-----------------------")
            

#Fecho o arquivo da professora Carolina
arquivoProfessoraCarolina.close()
arquivoProfessoraRosiane.close()
            

#enconding = 'cp1252'
#enconding = 'ISO-8859-1'

#Lê o arquivo de texto e corrige os acentos com o encoding
configuracaoIdioma = 'cp1252'
arquivoDataFrame = pd.read_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.txt', encoding=configuracaoIdioma )
df = pd.read_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.txt', encoding=configuracaoIdioma )


#Salva o arquivo em formato de tabela no excel
arquivoDataFrame.to_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraCarolina.csv', encoding='utf-8-sig')
df.to_csv('A:\\Python RPA\\Arquivo Texto e PDF\\ProfessoraRosiane.csv', encoding='utf-8-sig')
# Out:
# Professora:  Rosiane
# Aline Rosa
# Nota 1:  5
# Nota 2:  10
# Nota 3:  7
# Nota 4:  7
# Faltas:  2
# Média:  7.25
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Amanda Martins
# Nota 1:  6
# Nota 2:  10
# Nota 3:  10
# Nota 4:  9
# Faltas:  3
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Angela Maria
# Nota 1:  8
# Nota 2:  10
# Nota 3:  7
# Nota 4:  10
# Faltas:  5
# Média:  8.75
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Carlos Moreira
# Nota 1:  10
# Nota 2:  4
# Nota 3:  7
# Nota 4:  6
# Faltas:  2
# Média:  6.75
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Eliane Moreira
# Nota 1:  10
# Nota 2:  6
# Nota 3:  5
# Nota 4:  4
# Faltas:  3
# Média:  6.25
# Aprovado(a)
# -----------------------
# Professora:  Rosiane
# Leonardo Almeida
# Nota 1:  8
# Nota 2:  9
# Nota 3:  6
# Nota 4:  9
# Faltas:  2
# Média:  8.0
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota 1:  1
# Nota 2:  2
# Nota 3:  2
# Nota 4:  2
# Faltas:  3
# Média:  1.75
# Reprovado(a) por Média
# -----------------------
# Professora:  Rosiane
# Paulo Santos
# Nota 1:  9
# Nota 2:  7
# Nota 3:  10
# Nota 4:  9
# Faltas:  0
# Média:  8.75
# Aprovado(a)
# -----------------------
# Professora:  Carolina
# Raul Silva
# Nota 1:  8
# Nota 2:  10
# Nota 3:  5
# Nota 4:  10
# Faltas:  4
# Média:  8.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Rosiane
# Reinaldo Assis
# Nota 1:  8
# Nota 2:  8
# Nota 3:  8
# Nota 4:  5
# Faltas:  5
# Média:  7.25
# Reprovado(a) por falta
# -----------------------
# Professora:  Carolina
# Eduardo Pires
# Nota 1:  8
# Nota 2:  9
# Nota 3:  8
# Nota 4:  9
# Faltas:  1
# Média:  8.5
# Aprovado(a)
# -----------------------

# %%
import pandas as opcoesPandas
import os

#Caminho onde estão os arquivos
caminhoArquivos = "A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar"

#Variável onde estão todos os arquivos
listaArquivos = os.listdir(caminhoArquivos)

print(listaArquivos)

listaCaminhoEArquivoBlocoNotas = [caminhoArquivos + '\\' + arquivo for arquivo in listaArquivos if arquivo[-3:] == 'txt']

print(listaCaminhoEArquivoBlocoNotas)

#Criando os DataFrame para trabalhar com os Dados
dadosArquivo = opcoesPandas.DataFrame()

#Copiando todos os dados dos arquivos em dadosArquivo
for arquivo in listaCaminhoEArquivoBlocoNotas:
    
    #Pego as informações de cada bloco de notas e armazeno como um DF em Dados
    dados = opcoesPandas.read_csv(arquivo)
    
    #Junto / Consolido / Concateno os dados de todos os DF em dadosArquivo
    dadosArquivo = opcoesPandas.concat([dadosArquivo, dados])
    
#Criando uma nova planilha e passando os dados dos arquivos
#dadosArquivo.to_excel("A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo Consolidado.xlsx")
dadosArquivo.to_csv('A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo Consolidado.csv', encoding='utf-8-sig')
# Out:
# ['Arquivo1.txt', 'Arquivo2.txt', 'Arquivo3.txt', 'Arquivo4.txt', 'Arquivo5.txt']
# ['A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar\\Arquivo1.txt', 'A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar\\Arquivo2.txt', 'A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar\\Arquivo3.txt', 'A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar\\Arquivo4.txt', 'A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar\\Arquivo5.txt']

# %%
"""
EXERCÍCIO

1 - Consolidar os arquivos de textos, podem usar 
como base o código da aula passada

2 - Quebrar o texto em colunas

3 - Criar duas novas colunas e deixar em uma apenas o Nome
e na outra o Sobrenome

4 - Limpar o CPF e deixar somente no formato: 123.456.789-10

5 - Salvar os dados com os tratamentos em um arquivo de Excel

"""

# %%
import pandas as opcoesPandas
import os

arquivoTextoConsolidado = open("A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo_Exercicio_Bloco_Notas_Consolidado.txt", "w")

#Caminho onde estão os arquivos
caminhoArquivos = "A:\\Python RPA\\Arquivo Texto e PDF\\Arquivos_Consolidar"

#Variável onde estão todos os arquivos
listaArquivos = os.listdir(caminhoArquivos)

#print(listaArquivos)

listaCaminhoEArquivoBlocoNotas = [caminhoArquivos + '\\' + arquivo for arquivo in listaArquivos if arquivo[-3:] == 'txt']

#print(listaCaminhoEArquivoBlocoNotas)

#Criando os DataFrame para trabalhar com os Dados
dadosArquivo = opcoesPandas.DataFrame()

#Titulo
arquivoTextoConsolidado.write('Linha;Escola;ID;Aluno;Primeiro Nome;Sobrenome;CPF;Idade\n')

#Copiando todos os dados dos arquivos em dadosArquivo
for arquivo in listaCaminhoEArquivoBlocoNotas:
    
    #Pego as informações de cada bloco de notas e armazeno como um DF em Dados
    dados = opcoesPandas.read_csv(arquivo)
    
    #Percorrer todo o arquivo a partir da segunda linha
    for pulaTitulo, linha in dados.iterrows():
        
        #Quebramos o texto que estava tudo na mesma linha e separamos em linhas
        #['ABC;782707;Aline Rosa Ferreira;CPF: 12345678910;36']
        linha = [item.split(';', 0)[0] for item in linha]
        
        #Resposta da segunda questão
        #Separando a linha em colunas atravé do delimitador ;
        separaLinhasEmColunas = linha[0].split(';')
        
        escola = separaLinhasEmColunas[0]
        idAluno = separaLinhasEmColunas[1]
        aluno = separaLinhasEmColunas[2]
        cpf = separaLinhasEmColunas[3]
        idade = separaLinhasEmColunas[4]
        
        #Resposta da terceira questão
        #split quebra o nome em colunas através do espaço em branco
        #pego a posição 0 que é a primeira coluna
        primeiroNome = aluno.split(' ')[0] #Quebro em coluna e pego a coluna 0
        
        #split quebra o nome em colunas através do espaço em branco
        #pego a posição última coluna
        sobrenome = aluno.split(' ')[-1] #Quebro em coluna e pego a última coluna
        
        #Resposta da quarta questão
        #CPF: 12345678910
        #Pegando partes do CPF que veio dos arquivo de texto do bloco de notas
        cpf_parte1 = cpf[5:8] #três números a partir da 5 posição
        cpf_parte2 = cpf[8:11] #três números a partir da 8 posição
        cpf_parte3 = cpf[11:14] #três números a partir da 11 posição
        cpf_parte4 = cpf[14:16] #dois números a partir da 14 posição
        
        #No CPF estou juntando as partes e formando o CPF com os pontos e traço
        cpf = str(cpf_parte1) + "." + str(cpf_parte2) + "." + str(cpf_parte3) + "-" + str(cpf_parte4)
              
        #Salvo os dados em formato que o pandas reconhece para salvar no Excel
        #Salvo no Bloco de Notas
        arquivoTextoConsolidado.write(';' + escola + ';' + idAluno + ';' + aluno + ';' + primeiroNome + ';' + sobrenome + ';' + cpf + ';' + idade + '\n')
        

#Fecho o bloco de notas que tem todos os dados consolidados
arquivoTextoConsolidado.close 

idiomaParaAcentosDoArquivo = 'cp1252'

#Abro o arquivo do bloco de notas como csv
lerArquivoBlocoNotasConsolidado = pd.read_csv("A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo_Exercicio_Bloco_Notas_Consolidado.txt", encoding=idiomaParaAcentosDoArquivo)

#Criando uma nova planilha e passando os dados dos arquivos
#dadosArquivo.to_excel("A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo Consolidado.xlsx")
lerArquivoBlocoNotasConsolidado.to_csv('A:\\Python RPA\\Arquivo Texto e PDF\\Arquivo Final Exercicio Texto.csv', encoding='utf-8-sig')
